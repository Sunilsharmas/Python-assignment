# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
# a
a= pd.Series([100, 200, 300, 400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
print(type(a))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
print(a[2])
# Out:
# 300

# %% [markdown]
# What are the values of index for series a?

# %%
print(a.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a = pd.Series([100, 200, 300, 400])
a.index = ['c', 'a', 'b', 'd']
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Access the value in the series with index 'd'

# %%
print(a['d'])
# Out:
# 400

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
a.sort_index()
# Out:
# a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
# b =
import pandas as pd
b=pd.Series([800,450,100])
b.index=['e','f','g']
b
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
#print a again after appending b into it

a=pd.concat([a,b])
a
# Out:
# c    100
# a    200
# b    300
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
# a =
a=a.sort_values(ascending=False)
a
# Out:
# e    800
# f    450
# d    400
# b    300
# a    200
# c    100
# g    100
# dtype: int64

# %%
print(a.index)
# Out:
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
# df =

df=pd.DataFrame(a)
df
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200
# c  100
# g  100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
df.shape
# Out:
# (7, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
# yep its same as the series.

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
df.head()

#head show top 5 row data, and top show last 5 row data
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200

# %%
df.tail()
# Out:
#      0
# d  400
# b  300
# a  200
# c  100
# g  100

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df=df.rename({0:'points'},axis=1)
df
# Out:
#    points
# e     800
# f     450
# d     400
# b     300
# a     200
# c     100
# g     100

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
#Create fruits array

# fruits =
fruits= ['orange','mango','apple']

# Randomly select 7 fruits
fruits = np.random.choice(fruits,7)

fruits
# Out:
# array(['mango', 'apple', 'mango', 'orange', 'mango', 'orange', 'apple'],
#       dtype='<U6')

# %%
#Create series fruits out of fruits array

# fruits =
fruits=pd.Series(fruits)
fruits
# Out:
# 0     mango
# 1     apple
# 2     mango
# 3    orange
# 4     mango
# 5    orange
# 6     apple
# dtype: object

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruits.index=df.index
fruits
# Out:
# e     mango
# f     apple
# d     mango
# b    orange
# a     mango
# c    orange
# g     apple
# dtype: object

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df['fruits']=fruits
df.head()
# Out:
#    points  fruits
# e     800   mango
# f     450   apple
# d     400   mango
# b     300  orange
# a     200   mango

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
# d1 =

d1 = pd.DataFrame({
    'city': ['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali'],
    'Temperature': [15, 22, 20, 26, -2]
})

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
d1.shape
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city = d1['city']

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)
print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
# d2 =
d2=pd.DataFrame({'city':['Bengalaru','Coimbatore','Srirangam','Pondicherry'],'Temperature':[24,35,36,39]})
d2
# Out:
#           city  Temperature
# 0    Bengalaru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# print the shape of this dataframe

# %%
d2.shape
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
# d3 =

d3=pd.concat([d1,d2])
d3
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 0    Bengalaru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
check_temp=d3[(d3['Temperature']<=20)]
check_temp
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
check_temp1=d3[d3['Temperature']>=35]
check_temp1
# Out:
#           city  Temperature
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
def is_ut(x):
  union_territory=['Chandigarh','Pondicherry','Delhi']
  if x in union_territory:
    return True
  else:
    return False
d3['is_ut']=d3['city'].apply(is_ut)
d3
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 0    Bengalaru           24  False
# 1   Coimbatore           35  False
# 2    Srirangam           36  False
# 3  Pondicherry           39   True

# %%
# print d3

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
# write function here

def c_to_f(x):
  x= (x*9/5)+32
  return x

# %%
# check function c_to_f(10)

c_to_f(10)
# Out:
# 50.0

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'
d3['temp_farenhiet']=d3['Temperature'].apply(c_to_f)
d3
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 0   Chandigarh           15   True            59.0
# 1        Delhi           22   True            71.6
# 2       Kanpur           20  False            68.0
# 3      Chennai           26  False            78.8
# 4       Manali           -2  False            28.4
# 0    Bengalaru           24  False            75.2
# 1   Coimbatore           35  False            95.0
# 2    Srirangam           36  False            96.8
# 3  Pondicherry           39   True           102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
ut_cities=d3[d3['is_ut']==True]
ut_cities
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 0   Chandigarh           15   True            59.0
# 1        Delhi           22   True            71.6
# 3  Pondicherry           39   True           102.2

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
ut_cities1=d3[d3['temp_farenhiet']>90]
ut_cities1
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 1   Coimbatore           35  False            95.0
# 2    Srirangam           36  False            96.8
# 3  Pondicherry           39   True           102.2

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
d1.head(3)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
d3.iloc[ : ,-2: ]
# Out:
#    is_ut  temp_farenhiet
# 0   True            59.0
# 1   True            71.6
# 2  False            68.0
# 3  False            78.8
# 4  False            28.4
# 0  False            75.2
# 1  False            95.0
# 2  False            96.8
# 3   True           102.2

# %% [markdown]
# ## Groupby

# %%
# Create a dataframe using dictionary of your choice

# data =

data=pd.DataFrame({'Name':['sunil','rohan','shyam','rahul'],'age':[21,24,25,26]})
data
# Out:
#     Name  age
# 0  sunil   21
# 1  rohan   24
# 2  shyam   25
# 3  rahul   26

# %%
# Use Groupby of single column with aggregate sum()

grouped =d3.groupby('is_ut')[['Temperature', 'temp_farenhiet']].sum()
grouped
# Out:
#        Temperature  temp_farenhiet
# is_ut
# False          139           442.2
# True            76           232.8

# %%
# Use Groupby of single column with aggregate count()
count_ =d3.groupby('is_ut')[['Temperature', 'temp_farenhiet']].count()
count_
# Out:
#        Temperature  temp_farenhiet
# is_ut
# False            6               6
# True             3               3

# %%
# Use Groupby of single column with aggregate min() and max()

minimum =d3.groupby('is_ut')[['Temperature', 'temp_farenhiet']].min()
minimum
# Out:
#        Temperature  temp_farenhiet
# is_ut
# False           -2            28.4
# True            15            59.0

# %%
maximum =d3.groupby('is_ut')[['Temperature', 'temp_farenhiet']].max()
maximum
# Out:
#        Temperature  temp_farenhiet
# is_ut
# False           36            96.8
# True            39           102.2

# %%
# Use Groupby of any 2 columns with aggregate mean()

a# Group by 'is_ut' and 'Temperature', then take mean of numeric columns
grouped_mean = d3.groupby(['is_ut', 'Temperature']).mean(numeric_only=True)

print(grouped_mean)
# Out:
#                    temp_farenhiet
# is_ut Temperature
# False -2                     28.4
#        20                    68.0
#        24                    75.2
#        26                    78.8
#        35                    95.0
#        36                    96.8
# True   15                    59.0
#        22                    71.6
#        39                   102.2

# %%
# Use Groupby of any 2 columns with aggregate min() and max()

d3.groupby(['is_ut', 'Temperature']).agg(['min','max'])
# Out:
#                           city              temp_farenhiet
#                            min          max            min    max
# is_ut Temperature
# False -2                Manali       Manali           28.4   28.4
#        20               Kanpur       Kanpur           68.0   68.0
#        24            Bengalaru    Bengalaru           75.2   75.2
#        26              Chennai      Chennai           78.8   78.8
#        35           Coimbatore   Coimbatore           95.0   95.0
#        36            Srirangam    Srirangam           96.8   96.8
# True   15           Chandigarh   Chandigarh           59.0   59.0
#        22                Delhi        Delhi           71.6   71.6
#        39          Pondicherry  Pondicherry          102.2  102.2

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
# a =
a = pd.date_range(start='2020-01-01', end='2021-04-01')
a
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[ns]', length=457, freq='D')

# %% [markdown]
# print a

# %% [markdown]
# What is the len of a?

# %%
len(a)
# Out:
# 457

# %% [markdown]
# What is the type of a?

# %%
type(a)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex
